# %% [markdown]
# <a href="https://colab.research.google.com/github/Mujthaba-GM/-NLP/blob/main/Textpreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
